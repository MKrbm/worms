# %%
from bs4 import BeautifulSoup

# %%
def match_class(target):                                                        
    def do_match(tag):                                                          
        classes = tag.get('class', [])                                          
        return all(c in classes for c in target)                                
    return do_match  

url = "https://ncode.syosetu.com/n2267be/"
res = request.urlopen(url)
soup = BeautifulSoup(res, "html.parser")
title = soup.find_all(match_class(["novel_title"]))
# Out:
# []
# <html lang="ja" xml:lang="ja" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <title>Ｒｅ：ゼロから始める異世界生活</title>
# <meta content="text/javascript" http-equiv="Content-Script-Type"/>
# <meta content="text/css" http-equiv="Content-Style-Type"/>
# <meta content="telephone=no" name="format-detection"/>
# <meta content="website" property="og:type"/>
# <meta content="Ｒｅ：ゼロから始める異世界生活" property="og:title"/>
# <meta content="https://ncode.syosetu.com/n2267be/" property="og:url"/>
# <meta content="R15 残酷な描写あり 異世界転移 異世界 ファンタジー 銀髪ヒロイン 感想乞食 バトル シリアス ほのぼの 時間遡行 死に戻り" property="og:description"/>
# <meta content="https://sbo.syosetu.com/n2267be/twitter.png" property="og:image"/>
# <meta content="小説家になろう" property="og:site_name"/>
# <meta content="@syosetu" name="twitter:site"/>
# <meta content="summary_large_image" name="twitter:card"/>
# ...

# %%
import re
string = '<p class="novel_title">Ｒｅ：ゼロから始める異世界生活</p>'
pattern = '<p class="novel_title">(.*?)</p>'
match = re.search(pattern, string)

if match:
    print(match.group(1)) # prints Ｒｅ：ゼロから始める異世界生活
else:
    print('No match found')
# Out:
# Ｒｅ：ゼロから始める異世界生活

# %%
import time
from urllib import request
from bs4 import BeautifulSoup

num_parts = 1  # ここに作品の全部分数を指定

with open("novel.txt", "w", encoding="utf-8") as f:
    for part in range(1, num_parts+1):
        # 作品本文ページのURL
        url = "https://ncode.syosetu.com/n2267be/{:d}/".format(part)

        res = request.urlopen(url)
        soup = BeautifulSoup(res, "html.parser")

        # CSSセレクタで本文を指定
        honbun = soup.select_one("#novel_honbun").text
        honbun += "\n"  # 次の部分との間は念のため改行しておく
        
        # 保存
        f.write(honbun)
        
        print("part {:d} downloaded".format(part))  # 進捗を表示

        time.sleep(0.1)  # 次の部分取得までは1秒間の時間を空ける
# Out:
# part 1 downloaded
