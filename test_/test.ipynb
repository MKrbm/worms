# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(0)
x = np.random.rand(50)
y = 2 * x + 1 + 0.1 * np.random.randn(50)

plt.scatter(x, y)
plt.xlim(0, 2)
plt.ylim(1, 4)

plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
a
# Out:
# 1.9692732947309535

# %%
from sklearn.linear_model import LinearRegression


reg = LinearRegression()
reg.fit(x.reshape(-1, 1), y)

a, b = reg.coef_[0], reg.intercept_
print(f"a: {a}, b: {b}")

# 回帰直線
x_line = np.linspace(0, 1, 100)
y_line = (a) * x_line + b 

plt.scatter(x, y)
plt.plot(x_line, y_line, color='red')
plt.xlabel('x')
plt.ylabel('y')
plt.xlim(0, 2)
plt.ylim(1, 4)
plt.show()
# Out:
# a: 1.9692732947309535, b: 0.999278991586972

# %%
plt.scatter(x, y)
plt.plot(x_line, y_line, color='red')

# 残差をプロット
for xi, yi in zip(x, y):
    plt.plot([xi, xi], [yi, a * xi + b], color='green', linestyle='dashed')

plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
def squared_error(a, b, x, y):
    y_pred = a*x + b
    return np.sum(np.abs(y - y_pred))

# %%
import numpy as np
import matplotlib.pyplot as plt

# データの作成
np.random.seed(0)
X = np.sort(5 * np.random.rand(80, 1), axis=0)
y = np.sin(X).ravel()

# ノイズの追加
y[::5] += 3 * (0.5 - np.random.rand(16))

plt.plot(X, y, 'o')
plt.show()

# %%
from sklearn.linear_model import LinearRegression

# 線形回帰の学習
lr = LinearRegression()
lr.fit(X, y)

# 回帰直線の可視化
plt.plot(X, y, 'o')
plt.plot(X, lr.predict(X))
plt.show()

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical

(x_train, y_train), (x_test, y_test) = mnist.load_data()

# 前処理
x_train = x_train.reshape(-1, 28, 28, 1).astype(np.float32) / 255.0
x_test = x_test.reshape(-1, 28, 28, 1).astype(np.float32) / 255.0

y_train = to_categorical(y_train, num_classes=10)
y_test = to_categorical(y_test, num_classes=10)

# %%
import matplotlib.pyplot as plt

# MNISTデータセットのサンプル画像を表示
n = 10
fig, axs = plt.subplots(1, n, figsize=(n, 1))
for i in range(n):
    axs[i].imshow(x_train[i].reshape(28, 28), cmap='gray')
    axs[i].axis('off')
plt.show()

# %%
x_train.shape
# Out:
# (60000, 28, 28, 1)

# %%
x_train = x_train.astype(np.float32) / 255.0
x_test = x_test.astype(np.float32) / 255.0

# %%
# 正規化前のデータ
(x_train_raw, _), (_, _) = mnist.load_data()

# ヒストグラムをプロット
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 4))

ax1.hist(x_train_raw.flatten(), bins=50, color='blue', alpha=0.5)
ax1.set_title('Before Normalization')
ax1.set_xlabel('Pixel Value')
ax1.set_ylabel('Frequency')

ax2.hist(x_train.flatten(), bins=50, color='red', alpha=0.5)
ax2.set_title('After Normalization')
ax2.set_xlabel('Pixel Value')
ax2.set_ylabel('Frequency')

plt.show()

# %%
import matplotlib.pyplot as plt

sample_image = x_train[0]

# グレースケール画像のチャンネルを表示
fig, axs = plt.subplots(1, 2, figsize=(6, 3))

# 元のグレースケール画像を表示
axs[0].imshow(sample_image.reshape(28, 28), cmap='gray')
axs[0].set_title('Original Grayscale Image')
axs[0].axis('off')

# チャンネルを表示
axs[1].imshow(sample_image[:, :, 0], cmap='gray')
axs[1].set_title('Grayscale Channel')
axs[1].axis('off')

plt.show()

# %%
sample_image.reshape(28, 28).shape
# Out:
# (28, 28)
