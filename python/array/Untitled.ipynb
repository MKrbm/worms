# %%
import numpy as np

# %%
X = np.load("majumdar_ghosh/optimize8/0.npy")

# %%
Y = np.load("majumdar_ghosh/1D_chain/0.npy")

# %%
Y
# Out:
# array([[-2.25,  0.  ,  0.  , ...,  0.  ,  0.  ,  0.  ],
#        [ 0.  , -1.75, -0.25, ...,  0.  ,  0.  ,  0.  ],
#        [ 0.  , -0.25, -0.75, ...,  0.  ,  0.  ,  0.  ],
#        ...,
#        [ 0.  ,  0.  ,  0.  , ..., -0.75, -0.25,  0.  ],
#        [ 0.  ,  0.  ,  0.  , ..., -0.25, -1.75,  0.  ],
#        [ 0.  ,  0.  ,  0.  , ...,  0.  ,  0.  , -2.25]])

# %%
X
# Out:
# array([[ 7.49999703e-01,  8.29875265e-07, -5.18162311e-04, ...,
#          6.04047853e-08, -5.22534793e-12,  6.34794819e-09],
#        [ 8.29875265e-07,  1.49999541e+00,  3.06914096e-03, ...,
#          8.13139666e-06,  5.70620640e-05,  6.64532642e-08],
#        [-5.18162311e-04,  3.06914096e-03, -7.49995700e-01, ...,
#          6.68120739e-09,  2.24992357e-08, -1.28284085e-08],
#        ...,
#        [ 6.04047853e-08,  8.13139666e-06,  6.68120739e-09, ...,
#         -1.49999896e+00,  6.59014688e-04,  1.04232076e-04],
#        [-5.22538007e-12,  5.70620640e-05,  2.24992357e-08, ...,
#          6.59014688e-04,  4.99999662e-01,  3.21443076e-04],
#        [ 6.34794821e-09,  6.64532642e-08, -1.28284085e-08, ...,
#          1.04232076e-04,  3.21443076e-04, -4.99999829e-01]])

# %%
np.linalg.eigvalsh(X)
# Out:
# array([-2.25      , -2.25      , -2.25      , -2.25      , -2.25      ,
#        -2.25      , -2.25      , -1.83859073, -1.83859073, -1.83859073,
#        -1.83859073, -1.83859073, -1.5       , -1.5       , -1.5       ,
#        -1.5       , -1.5       , -1.23245494, -1.23245494, -1.23245494,
#        -0.70791833, -0.70791833, -0.70791833, -0.70791833, -0.70791833,
#        -0.41800601, -0.41800601, -0.41800601, -0.32632054, -0.32632054,
#        -0.32632054, -0.25      ,  0.5       ,  0.5       ,  0.5       ,
#         0.5       ,  0.5       ,  0.72366884,  0.72366884,  0.72366884,
#         0.86759845,  0.86759845,  0.86759845,  1.25      ,  1.25      ,
#         1.25      ,  1.25      ,  1.25      ,  1.29650906,  1.29650906,
#         1.29650906,  1.29650906,  1.29650906,  1.7828625 ,  1.7828625 ,
#         1.7828625 ,  1.8526517 ,  1.8526517 ,  1.8526517 ,  2.25      ,
#         2.25      ,  2.25      ,  2.25      ,  2.25      ])

# %%
print(np.linalg.eigvalsh(Y))
# Out:
# [-2.25       -2.25       -2.25       -2.25       -2.25       -2.25
#  -2.25       -1.83859073 -1.83859073 -1.83859073 -1.83859073 -1.83859073
#  -1.5        -1.5        -1.5        -1.5        -1.5        -1.23245494
#  -1.23245494 -1.23245494 -0.70791833 -0.70791833 -0.70791833 -0.70791833
#  -0.70791833 -0.41800601 -0.41800601 -0.41800601 -0.32632054 -0.32632054
#  -0.32632054 -0.25        0.5         0.5         0.5         0.5
#   0.5         0.72366884  0.72366884  0.72366884  0.86759845  0.86759845
#   0.86759845  1.25        1.25        1.25        1.25        1.25
#   1.29650906  1.29650906  1.29650906  1.29650906  1.29650906  1.7828625
#   1.7828625   1.7828625   1.8526517   1.8526517   1.8526517   2.25
#   2.25        2.25        2.25        2.25      ]

# %%
20.5994191174491/4
# Out:
# 5.15028
