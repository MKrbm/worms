# %%
from exact.utils import *

# %%
import os
import numpy as np
import pandas as pd
os.chdir("/home/user/project/execute")
T =  np.logspace(-1, 0.5, num=10)
J = np.arange(0.1, 1.1, 0.1)
df_s = pd.DataFrame(index=J, columns = T)
df_s_err = pd.DataFrame(index=J, columns = T)
df_e = pd.DataFrame(index=J, columns = T)
df_e_err = pd.DataFrame(index=J, columns = T)

# %%
import os
import numpy as np
import pandas as pd
os.chdir("/home/user/project/execute")
T =  np.logspace(-1, 0.5, num=10)
J = np.arange(0.1, 1.1, 0.1)
df_s = pd.DataFrame(index=J, columns = T)
df_s_err = pd.DataFrame(index=J, columns = T)
df_e = pd.DataFrame(index=J, columns = T)
df_e_err = pd.DataFrame(index=J, columns = T)

import subprocess
energy_array = []
sign_array = []
time_array = []
for t in T:
    for j in J:
        out = subprocess.Popen(["/home/user/project/Release/main", "-m", "SS2", "-ham", f"../python/array/SS/dimer_optm_J_[{j:.2}, 1]", "-T", f"{t}"], 
                   stdout=subprocess.PIPE, 
                   stderr=subprocess.STDOUT)
        stdout,stderr = out.communicate()

        energy, sign, dimer, time = process_line(stdout)
        print(f"T = {t} J = {j}",energy)
        df_s.loc[j][t], df_s_err.loc[j][t] = sign
        df_e.loc[j][t], df_e_err.loc[j][t] = energy
        
#         energy_array.append(energy)
#         sign_array.append(sign)
#         time_array.append(time)
# Out:
# T = 0.1 J = 0.1 [-5.99662, 0.00357098]
# T = 0.1 J = 0.2 [-6.00214, 0.00368342]
# T = 0.1 J = 0.30000000000000004 [-5.99036, 0.00363757]
# T = 0.1 J = 0.4 [-5.99406, 0.00365814]
# T = 0.1 J = 0.5 [-4.75898, 2.50085]
# T = 0.1 J = 0.6 [-6.75683, 8.62576]
# T = 0.1 J = 0.7000000000000001 [-7.8587, 7.47663]
# T = 0.1 J = 0.8 [-7.08675, 23.2656]
# T = 0.1 J = 0.9 [-9.90909, 10.2687]
# T = 0.1 J = 1.0 [-10.2686, 29.8423]
# T = 0.14677992676220694 J = 0.1 [-5.96332, 0.00436413]
# T = 0.14677992676220694 J = 0.2 [-5.96639, 0.00451784]
# T = 0.14677992676220694 J = 0.30000000000000004 [-5.9522, 0.00479649]
# T = 0.14677992676220694 J = 0.4 [-5.91837, 0.0052346]
# T = 0.14677992676220694 J = 0.5 [-5.84416, 0.148702]
# T = 0.14677992676220694 J = 0.6 [7.13754, 405.661]
# T = 0.14677992676220694 J = 0.7000000000000001 [-8.80669, 14.1611]
# T = 0.14677992676220694 J = 0.8 [-9.96368, 11.7914]
# T = 0.14677992676220694 J = 0.9 [-11.5177, 11.4994]
# ...

# %%
import os
import numpy as np
import pandas as pd
os.chdir("/home/user/project/execute")
T =  np.logspace(-1, 0.5, num=10)
J = np.arange(0.1, 1.1, 0.1)
df2_s = pd.DataFrame(index=J, columns = T)
df2_s_err = pd.DataFrame(index=J, columns = T)
df2_e = pd.DataFrame(index=J, columns = T)
df2_e_err = pd.DataFrame(index=J, columns = T)

import subprocess
energy_array = []
sign_array = []
time_array = []
for t in T:
    for j in J:
        out = subprocess.Popen(["/home/user/project/Release/main", "-m", "SS1", "-T", f"{t}", "-J1", f"{j:.2}"], 
                   stdout=subprocess.PIPE, 
                   stderr=subprocess.STDOUT)
        stdout,stderr = out.communicate()

        energy, sign, dimer, time = process_line(stdout)
        print(f"T = {t} J = {j}",energy)
        df2_s.loc[j][t], df2_s_err.loc[j][t] = sign
        df2_e.loc[j][t], df2_e_err.loc[j][t] = energy
        
#         energy_array.append(energy)
#         sign_array.append(sign)
#         time_array.append(time)
# Out:
# T = 0.1 J = 0.1 [-5.98617, 0.0319202]
# T = 0.1 J = 0.2 [-5.99361, 0.179501]
# T = 0.1 J = 0.30000000000000004 [-7.93133, 21.8335]
# T = 0.1 J = 0.4 [-13.2902, 29.2058]
# T = 0.1 J = 0.5 [-9.69396, 21.9019]
# T = 0.1 J = 0.6 [-2.14298, 25.5471]
# T = 0.1 J = 0.7000000000000001 [-9.35354, 16.9894]
# T = 0.1 J = 0.8 [-11.4496, 6.90861]
# T = 0.1 J = 0.9 [-10.7633, 9.28112]
# T = 0.1 J = 1.0 [-21.6479, 166.212]
# T = 0.14677992676220694 J = 0.1 [-5.9609, 0.0255429]
# T = 0.14677992676220694 J = 0.2 [-6.01312, 0.0981574]
# T = 0.14677992676220694 J = 0.30000000000000004 [-5.86854, 1.12942]
# T = 0.14677992676220694 J = 0.4 [-7.4775, 13.8733]
# T = 0.14677992676220694 J = 0.5 [-7.92377, 11.0602]
# T = 0.14677992676220694 J = 0.6 [-54.3149, 2176.28]
# T = 0.14677992676220694 J = 0.7000000000000001 [-3.28238, 33.1812]
# T = 0.14677992676220694 J = 0.8 [-10.7446, 7.85338]
# T = 0.14677992676220694 J = 0.9 [-5.18204, 66.5564]
# T = 0.14677992676220694 J = 1.0 [-14.345, 31.5326]
# ...

# %%
import os
import numpy as np
import pandas as pd
os.chdir("/home/user/project/execute")
T =  np.logspace(-1, 0.5, num=10)
J = np.arange(0.1, 1.1, 0.1)
df3_s = pd.DataFrame(index=J, columns = T)
df3_s_err = pd.DataFrame(index=J, columns = T)
df3_e = pd.DataFrame(index=J, columns = T)
df3_e_err = pd.DataFrame(index=J, columns = T)

import subprocess
energy_array = []
sign_array = []
time_array = []
for t in T:
    for j in J:
        out = subprocess.Popen(["/home/user/project/Release/main", "-m", "SS2", "-T", f"{t}", "-J1", f"{j:.2}",
                               "-ham", f"../python/array/SS/dimer_basis_J_[{j:.2}, 1]"], 
                   stdout=subprocess.PIPE, 
                   stderr=subprocess.STDOUT)
        stdout,stderr = out.communicate()

        energy, sign, dimer, time = process_line(stdout)
        print(f"T = {t} J = {j}",energy)
        df3_s.loc[j][t], df3_s_err.loc[j][t] = sign
        df3_e.loc[j][t], df3_e_err.loc[j][t] = energy
        
#         energy_array.append(energy)
#         sign_array.append(sign)
#         time_array.append(time)
# Out:
# T = 0.1 J = 0.1 [-3.18251, 0.00125993]
# T = 0.1 J = 0.2 [-3.52521, 0.00118107]
# T = 0.1 J = 0.30000000000000004 [-3.85452, 0.00114171]
# T = 0.1 J = 0.4 [-4.16612, 0.00112147]
# T = 0.1 J = 0.5 [-4.47849, 0.00113426]
# T = 0.1 J = 0.6 [-4.78639, 0.00113262]
# T = 0.1 J = 0.7000000000000001 [-5.09115, 0.00114575]
# T = 0.1 J = 0.8 [-5.39218, 0.00117413]
# T = 0.1 J = 0.9 [-5.69629, 0.00118831]
# T = 0.1 J = 1.0 [-5.99614, 0.00120269]
# T = 0.14677992676220694 J = 0.1 [-2.99566, 0.0011893]
# T = 0.14677992676220694 J = 0.2 [-3.32391, 0.00129499]
# T = 0.14677992676220694 J = 0.30000000000000004 [-3.62503, 0.00154977]
# T = 0.14677992676220694 J = 0.4 [-3.89936, 0.00257763]
# T = 0.14677992676220694 J = 0.5 [-4.13923, 0.0118947]
# T = 0.14677992676220694 J = 0.6 [-4.25014, 1.50564]
# T = 0.14677992676220694 J = 0.7000000000000001 [-150.103, 15027.2]
# T = 0.14677992676220694 J = 0.8 [-33.771, 37.8276]
# T = 0.14677992676220694 J = 0.9 [-36.7551, 21.0702]
# ...

# %% [markdown]
# ## save to csv

# %%
# df3_s= pd.read_csv("df3_s"), df3_s_err= pd.read_csv("df3_s_err"), df3_e= pd.read_csv("df3_e"), df3_e_err.to_csv("df3_e_err")
# df2_s.to_csv("df3_s"), df2_s_err.to_csv("df3_s_err"), df2_e.to_csv("df3_e"), df2_e_err.to_csv("df3_e_err")
# df1_s.to_csv("df3_s"), df1_s_err.to_csv("df3_s_err"), df1_e.to_csv("df3_e"), df1_e_err.to_csv("df3_e_err")

# %%
df1_s = pd.read_csv("df_s")

# %% [markdown]
# ## read from csv

# %%
os.chdir("/home/user/project/python/exact/SS/dataframe")
df1_s = pd.read_csv("df_s", index_col=0) # dimer lattice with optimized basis
df2_s = pd.read_csv("df2_s", index_col=0) # original 
df3_s = pd.read_csv("df3_s", index_col=0) # singlet-triplet basis
df1_s.index = np.round(df1_s.index, 3)
df2_s.index = np.round(df2_s.index, 3)
df3_s.index = np.round(df3_s.index, 3)
df1_s.columns = pd.to_numeric(df1_s.columns)
df2_s.columns = pd.to_numeric(df2_s.columns)
df3_s.columns = pd.to_numeric(df3_s.columns)

# %%
from matplotlib.lines import Line2D
legend_elements = []
legend_elements.append(Line2D([0], [0],  color="black", marker = "s", linestyle="-", label = "optimized"))
legend_elements.append(Line2D([0], [0],  color="black", marker = "o", linestyle="--", label = "original"))
legend_elements.append(Line2D([0], [0],  color="black", marker = "x", linestyle=":", label = "singlet-triplet"))

# %%
import matplotlib as mpl
legends = [c for c in ax[0].get_children() if isinstance(c, mpl.legend.Legend)]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [7], line 2
#       1 import matplotlib as mpl
# ----> 2 legends = [c for c in ax[0].get_children() if isinstance(c, mpl.legend.Legend)]
#
# NameError: name 'ax' is not defined

# %%
from matplotlib import pyplot as plt
fig, ax = plt.subplots(2, 1, figsize=(20, 20))
p1 = df1_s.transpose().plot(y = df1_s.index, ax = ax[0], style='s-', colormap='rainbow')
leg = ax[0].legend(handles=p1.legend().legendHandles, fontsize=15, loc="center right")
ax[0].add_artist(leg)
# df2_s.transpose().plot(y = df2_s.index, ax = ax[0], style = "o--", colormap='rainbow', legend=False)
df3_s.transpose().plot(y = df1_s.index, ax = ax[0], style = "x:", colormap='rainbow', legend=False)
p1 = df1_s.transpose().plot(y = [0.3, 0.4, 0.5, 0.7], ax = ax[1], style='s-', colormap='rainbow')
leg = ax[1].legend(handles=p1.legend().legendHandles, fontsize=15, loc="center right")
ax[1].add_artist(leg)
# df2_s.transpose().plot(y = [0.3, 0.4, 0.5, 0.6], ax = ax[1], style = "o--", colormap='rainbow', legend=False)
df3_s.transpose().plot(y = [0.3, 0.4, 0.5,  0.7], ax = ax[1], style = "x:", colormap='rainbow', legend=False)
for ax_ in ax:
    leg = ax_.legend(handles=legend_elements, fontsize=15, loc="lower right")

ax[0].set_xscale('log')
ax[1].set_xscale('log')

# %%
import os
import numpy as np
import pandas as pd
os.chdir("/home/user/project/execute")
T =  np.logspace(-1, 0.2, num=10)
J = np.arange(0.1, 1.1, 0.05)
df_s = pd.DataFrame(index=J, columns = T)
df_s_err = pd.DataFrame(index=J, columns = T)
df_e = pd.DataFrame(index=J, columns = T)
df_e_err = pd.DataFrame(index=J, columns = T)

import subprocess
energy_array = []
sign_array = []
time_array = []
for t in T:
    for j in J:
        out = subprocess.Popen(["/home/user/project/Release/main", "-m", "SS2", "-ham", f"../python/array/SS/dimer_optm_J_[{j:.2}, 1]", "-T", f"{t}", "-L1", "8", "-L2", "8"], 
                   stdout=subprocess.PIPE, 
                   stderr=subprocess.STDOUT)
        stdout,stderr = out.communicate()

        energy, sign, dimer, time = process_line(stdout)
        print(f"T = {t} J = {j}",energy)
        df_s.loc[j][t], df_s_err.loc[j][t] = sign
        df_e.loc[j][t], df_e_err.loc[j][t] = energy
# Out:
# T = 0.1 J = 0.1 [-95.9987, 0.0143067]
# T = 0.1 J = 0.15000000000000002 []
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [78], line 25
#      23 energy, sign, dimer, time = process_line(stdout)
#      24 print(f"T = {t} J = {j}",energy)
# ---> 25 df_s.loc[j][t], df_s_err.loc[j][t] = sign
#      26 df_e.loc[j][t], df_e_err.loc[j][t] = energy
#
# ValueError: not enough values to unpack (expected 2, got 0)

# %%
df2_s = pd.DataFrame(index=J, columns = T)
df2_s_err = pd.DataFrame(index=J, columns = T)
df2_e = pd.DataFrame(index=J, columns = T)
df2_e_err = pd.DataFrame(index=J, columns = T)

import subprocess
energy_array = []
sign_array = []
time_array = []
for t in T:
    for j in J:
        out = subprocess.Popen(["/home/user/project/Release/main", "-m", "SS1", "-T", f"{t}", "-J1", f"{j:.2}", "-L1", "4", "-L2", "4"], 
                   stdout=subprocess.PIPE, 
                   stderr=subprocess.STDOUT)
        stdout,stderr = out.communicate()

        energy, sign, dimer, time = process_line(stdout)
        print(f"T = {t} J = {j}",energy)
        df2_s.loc[j][t], df2_s_err.loc[j][t] = sign
        df2_e.loc[j][t], df2_e_err.loc[j][t] = energy

# %%
df3_s = pd.DataFrame(index=J, columns = T)
df3_s_err = pd.DataFrame(index=J, columns = T)
df3_e = pd.DataFrame(index=J, columns = T)
df3_e_err = pd.DataFrame(index=J, columns = T)

import subprocess
energy_array = []
sign_array = []
time_array = []
for t in T:
    for j in J:
        out = subprocess.Popen(["/home/user/project/Release/main", "-m", "SS2", "-T", f"{t}", "-J1", f"{j:.2}",
                               "-ham", f"../python/array/SS/dimer_basis_J_[{j:.2}, 1]", "-L1", "8", "-L2", "8"], 
                   stdout=subprocess.PIPE, 
                   stderr=subprocess.STDOUT)
        stdout,stderr = out.communicate()

        energy, sign, dimer, time = process_line(stdout)
        print(f"T = {t} J = {j}",energy)
        df3_s.loc[j][t], df3_s_err.loc[j][t] = sign
        df3_e.loc[j][t], df3_e_err.loc[j][t] = energy
        
#         energy_array.append(energy)
#         sign_array.append(sign)
#         time_array.append(time)

# %% [markdown]
# ## to csv

# %%
# os.chdir("/home/user/project/python/exact/SS/dataframe")
# df_s.to_csv(f"s_dimer_optim_L=[8,8]")
# df_s_err.to_csv(f"se_dimer_optim_L=[8,8]")
# df_e.to_csv(f"e_dimer_optim_L=[8,8]")
# df_e_err.to_csv(f"ee_dimer_optim_L=[8,8]")

# df2_s.to_csv(f"s_original_L=[8,8]")
# df2_s_err.to_csv(f"se_original_L=[8,8]")
# df2_e.to_csv(f"e_original_L=[8,8]")
# df2_e_err.to_csv(f"ee_original_L=[8,8]")

# df3_s.to_csv(f"s_dimer_singlet-triplet_L=[8,8]")
# df3_s_err.to_csv(f"se_dimer_singlet-triplet_L=[8,8]")
# df3_e.to_csv(f"e_dimer_singlet-triplet_L=[8,8]")
# df3_e_err.to_csv(f"ee_dimer_singlet-triplet_L=[8,8]")

# %% [markdown]
# ## read csv

# %%
os.chdir("/home/user/project/python/exact/SS/dataframe")
df1_s= pd.read_csv(f"s_dimer_optim_L=[8,8]", index_col=0)
df2_s= pd.read_csv(f"s_original_L=[8,8]", index_col=0)
df3_s= pd.read_csv(f"s_dimer_singlet-triplet_L=[8,8]", index_col=0)
df1_s.index = np.round(df1_s.index, 3)
df2_s.index = np.round(df2_s.index, 3)
df3_s.index = np.round(df3_s.index, 3)
df1_s.columns = pd.to_numeric(df1_s.columns)
df2_s.columns = pd.to_numeric(df2_s.columns)
df3_s.columns = pd.to_numeric(df3_s.columns)

# %%
from matplotlib import pyplot as plt
fig, ax = plt.subplots(2, 1, figsize=(20, 20))
p1 = df1_s.transpose().plot(y = df1_s.index, ax = ax[0], style='s-', colormap='rainbow')
leg = ax[0].legend(handles=p1.legend().legendHandles, fontsize=15, loc="center right")
ax[0].add_artist(leg)
# df2_s.transpose().plot(y = df2_s.index, ax = ax[0], style = "o--", colormap='rainbow', legend=False)
df3_s.transpose().plot(y = df1_s.index, ax = ax[0], style = "x:", colormap='rainbow', legend=False)
p1 = df1_s.transpose().plot(y = [0.3, 0.4, 0.5, 0.7], ax = ax[1], style='s-', colormap='rainbow')
leg = ax[1].legend(handles=p1.legend().legendHandles, fontsize=15, loc="center right")
ax[1].add_artist(leg)
# df2_s.transpose().plot(y = [0.3, 0.4, 0.5, 0.6], ax = ax[1], style = "o--", colormap='rainbow', legend=False)
df3_s.transpose().plot(y = [0.3, 0.4, 0.5,  0.7], ax = ax[1], style = "x:", colormap='rainbow', legend=False)
for ax_ in ax:
    leg = ax_.legend(handles=legend_elements, fontsize=15, loc="lower right")

ax[0].set_xscale('log')
ax[1].set_xscale('log')
