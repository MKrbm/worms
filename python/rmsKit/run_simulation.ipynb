# %%
import utils

# %%
share_path = "../python/rmsKit/array/torch/FF1D_loc/"
ham_path = share_path + "s_3_r_2_lt_1_d_1_seed_0/original_mel_LION/lr_0.005_epoch_20000/H/"
u_path = share_path + "s_3_r_2_lt_1_d_1_seed_0/original_mel_LION/lr_0.005_epoch_20000/loss_0.17387/u/"

utils.run_worm("FF_1D", ham_path, u_path, [6], 1.0, int(1E6), 1)
# Out:
# "../worm_result/FF_1D_L_6/T_1.000000/N_1000000"
# CompletedProcess(args=['mpirun', '-n', '1', 'main_MPI', '-m', 'FF_1D', '-T', '1.0', '-ham', '../python/rmsKit/array/torch/FF1D_loc/s_3_r_2_lt_1_d_1_seed_0/original_mel_LION/lr_0.005_epoch_20000/H/', '-unitary', '../python/rmsKit/array/torch/FF1D_loc/s_3_r_2_lt_1_d_1_seed_0/original_mel_LION/lr_0.005_epoch_20000/loss_0.17387/u/', '-N', '1000000', '-L1', '6', '', '', '--output', '-L1', '6'], returncode=0)

# %%
for s in range(10):
    print(run_ff_1d(seed=s+1, rank=2, sps=3, lt=1, e = 2*(10**4), M = 100 ).stdout)
# Out:
# Optimization successfully.
# Command: python torch_optimize_loc.py -m FF1D -loss mel -o LION -e 20000 -M 100 -lr 0.005 --seed 1
#                 settings = {'sps': 3, 'rank': 2, 'dimension': 1, 'lt': 1, 'seed': 1, 'M': 100, 'e': 20000}
#
# logging to file: optimizer_output/2023-10-29_23-51-28_optimizer.log
# logging to tensorboard under: out/tensorboard/FF1D_loc/s_3_r_2_lt_1_d_1_seed_1/original_mel_LION/lr_0.005_epoch_20000
#
# Optimization successfully.
# Command: python torch_optimize_loc.py -m FF1D -loss mel -o LION -e 20000 -M 100 -lr 0.005 --seed 2
#                 settings = {'sps': 3, 'rank': 2, 'dimension': 1, 'lt': 1, 'seed': 2, 'M': 100, 'e': 20000}
#
# logging to file: optimizer_output/2023-10-30_00-06-17_optimizer.log
# logging to tensorboard under: out/tensorboard/FF1D_loc/s_3_r_2_lt_1_d_1_seed_2/original_mel_LION/lr_0.005_epoch_20000
#
# Optimization successfully.
# Command: python torch_optimize_loc.py -m FF1D -loss mel -o LION -e 20000 -M 100 -lr 0.005 --seed 3
#                 settings = {'sps': 3, 'rank': 2, 'dimension': 1, 'lt': 1, 'seed': 3, 'M': 100, 'e': 20000}
#
# logging to file: optimizer_output/2023-10-30_00-21-50_optimizer.log
# logging to tensorboard under: out/tensorboard/FF1D_loc/s_3_r_2_lt_1_d_1_seed_3/original_mel_LION/lr_0.005_epoch_20000
#
# Optimization successfully.
# Command: python torch_optimize_loc.py -m FF1D -loss mel -o LION -e 20000 -M 100 -lr 0.005 --seed 4
#                 settings = {'sps': 3, 'rank': 2, 'dimension': 1, 'lt': 1, 'seed': 4, 'M': 100, 'e': 20000}
#
# logging to file: optimizer_output/2023-10-30_00-38-25_optimizer.log
# logging to tensorboard under: out/tensorboard/FF1D_loc/s_3_r_2_lt_1_d_1_seed_4/original_mel_LION/lr_0.005_epoch_20000
#
# Optimization successfully.
# Command: python torch_optimize_loc.py -m FF1D -loss mel -o LION -e 20000 -M 100 -lr 0.005 --seed 5
#                 settings = {'sps': 3, 'rank': 2, 'dimension': 1, 'lt': 1, 'seed': 5, 'M': 100, 'e': 20000}
#
# logging to file: optimizer_output/2023-10-30_02-26-13_optimizer.log
# logging to tensorboard under: out/tensorboard/FF1D_loc/s_3_r_2_lt_1_d_1_seed_5/original_mel_LION/lr_0.005_epoch_20000
#
# Optimization successfully.
# Command: python torch_optimize_loc.py -m FF1D -loss mel -o LION -e 20000 -M 100 -lr 0.005 --seed 6
#                 settings = {'sps': 3, 'rank': 2, 'dimension': 1, 'lt': 1, 'seed': 6, 'M': 100, 'e': 20000}
#
# logging to file: optimizer_output/2023-10-30_04-17-46_optimizer.log
# logging to tensorboard under: out/tensorboard/FF1D_loc/s_3_r_2_lt_1_d_1_seed_6/original_mel_LION/lr_0.005_epoch_20000
#
# Optimization successfully.
# Command: python torch_optimize_loc.py -m FF1D -loss mel -o LION -e 20000 -M 100 -lr 0.005 --seed 7
#                 settings = {'sps': 3, 'rank': 2, 'dimension': 1, 'lt': 1, 'seed': 7, 'M': 100, 'e': 20000}
#
# logging to file: optimizer_output/2023-10-30_06-01-42_optimizer.log
# logging to tensorboard under: out/tensorboard/FF1D_loc/s_3_r_2_lt_1_d_1_seed_7/original_mel_LION/lr_0.005_epoch_20000
#
# Optimization successfully.
# Command: python torch_optimize_loc.py -m FF1D -loss mel -o LION -e 20000 -M 100 -lr 0.005 --seed 8
#                 settings = {'sps': 3, 'rank': 2, 'dimension': 1, 'lt': 1, 'seed': 8, 'M': 100, 'e': 20000}
#
# logging to file: optimizer_output/2023-10-30_07-56-20_optimizer.log
# logging to tensorboard under: out/tensorboard/FF1D_loc/s_3_r_2_lt_1_d_1_seed_8/original_mel_LION/lr_0.005_epoch_20000
#
# Optimization successfully.
# Command: python torch_optimize_loc.py -m FF1D -loss mel -o LION -e 20000 -M 100 -lr 0.005 --seed 9
#                 settings = {'sps': 3, 'rank': 2, 'dimension': 1, 'lt': 1, 'seed': 9, 'M': 100, 'e': 20000}
#
# logging to file: optimizer_output/2023-10-30_09-21-52_optimizer.log
# logging to tensorboard under: out/tensorboard/FF1D_loc/s_3_r_2_lt_1_d_1_seed_9/original_mel_LION/lr_0.005_epoch_20000
#
# Optimization successfully.
# Command: python torch_optimize_loc.py -m FF1D -loss mel -o LION -e 20000 -M 100 -lr 0.005 --seed 10
#                 settings = {'sps': 3, 'rank': 2, 'dimension': 1, 'lt': 1, 'seed': 10, 'M': 100, 'e': 20000}
#
# logging to file: optimizer_output/2023-10-30_10-28-00_optimizer.log
# logging to tensorboard under: out/tensorboard/FF1D_loc/s_3_r_2_lt_1_d_1_seed_10/original_mel_LION/lr_0.005_epoch_20000

# %%
utils.run_worm('test', 'ham', 'u', [2, 2, 2], 100, 1.0)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 utils.run_worm('test', 'ham', 'u', [2, 2, 2], 100, 1.0)
#
# AttributeError: module 'utils' has no attribute 'run_worm'

# %%
import numpy as np
# T = np.concatenate([np.logspace(-1.8, -1, num=5)[:-1], np.logspace(-1, 0, num=10)])
T = np.logspace(-1, 0, num=10)

# %%
import glob
import re
share_path = "../python/rmsKit/array/torch/FF1D_loc/"

for s in range(6):
    ham_path = share_path + f"s_3_r_2_lt_1_d_1_seed_{s}/original_mel_LION/lr_0.005_epoch_20000/H/"
    parent_dir = f"array/torch/FF1D_loc/s_3_r_2_lt_1_d_1_seed_{s}/original_mel_LION/lr_0.005_epoch_20000"
    min_path, min_loss = utils.path_with_lowest_loss(parent_dir)
    u_path = "../python/rmsKit/" + min_path + "/u"
    for t in T:
        print(f"seed = {s} T = {t}")
        utils.run_worm("FF_1D", ham_path, "", [6], t, int(1E6), 4)
# Out:
# seed = 0 T = 0.1
# seed = 0 T = 0.1291549665014884
# seed = 0 T = 0.16681005372000587
# seed = 0 T = 0.21544346900318834
# seed = 0 T = 0.2782559402207124
# seed = 0 T = 0.35938136638046275
# seed = 0 T = 0.46415888336127786
# seed = 0 T = 0.5994842503189409
# seed = 0 T = 0.774263682681127
# seed = 0 T = 1.0
# seed = 1 T = 0.1
# seed = 1 T = 0.1291549665014884
# seed = 1 T = 0.16681005372000587
# seed = 1 T = 0.21544346900318834
# seed = 1 T = 0.2782559402207124
# seed = 1 T = 0.35938136638046275
# seed = 1 T = 0.46415888336127786
# seed = 1 T = 0.5994842503189409
# seed = 1 T = 0.774263682681127
# seed = 1 T = 1.0
# seed = 2 T = 0.1
# seed = 2 T = 0.1291549665014884
# seed = 2 T = 0.16681005372000587
# seed = 2 T = 0.21544346900318834
# seed = 2 T = 0.2782559402207124
# seed = 2 T = 0.35938136638046275
# seed = 2 T = 0.46415888336127786
# seed = 2 T = 0.5994842503189409
# seed = 2 T = 0.774263682681127
# seed = 2 T = 1.0
# seed = 3 T = 0.1
# seed = 3 T = 0.1291549665014884
# seed = 3 T = 0.16681005372000587
# seed = 3 T = 0.21544346900318834
# seed = 3 T = 0.2782559402207124
# seed = 3 T = 0.35938136638046275
# seed = 3 T = 0.46415888336127786
# seed = 3 T = 0.5994842503189409
# seed = 3 T = 0.774263682681127
# seed = 3 T = 1.0
# seed = 4 T = 0.1
# seed = 4 T = 0.1291549665014884
# seed = 4 T = 0.16681005372000587
# seed = 4 T = 0.21544346900318834
# seed = 4 T = 0.2782559402207124
# seed = 4 T = 0.35938136638046275
# seed = 4 T = 0.46415888336127786
# seed = 4 T = 0.5994842503189409
# seed = 4 T = 0.774263682681127
# seed = 4 T = 1.0
# seed = 5 T = 0.1
# seed = 5 T = 0.1291549665014884
# seed = 5 T = 0.16681005372000587
# seed = 5 T = 0.21544346900318834
# seed = 5 T = 0.2782559402207124
# seed = 5 T = 0.35938136638046275
# seed = 5 T = 0.46415888336127786
# seed = 5 T = 0.5994842503189409
# seed = 5 T = 0.774263682681127
# seed = 5 T = 1.0

# %% [markdown]
# ## Calculate for different L

# %%
import numpy as np
import utils

L = np.int64(np.logspace(0.8, 2, num = 10))
T = np.logspace(-1, 0, num=4)

# %%
share_path = "../python/rmsKit/array/torch/FF1D_loc/"

for s in range(6):
    ham_path = share_path + f"s_3_r_2_lt_1_d_1_seed_{s}/original_mel_LION/lr_0.005_epoch_20000/H/"
    parent_dir = f"array/torch/FF1D_loc/s_3_r_2_lt_1_d_1_seed_{s}/original_mel_LION/lr_0.005_epoch_20000"
    min_path, min_loss = utils.path_with_lowest_loss(parent_dir)
    u_path = "../python/rmsKit/" + min_path + "/u"
    for t in T:
        for l in L:
            print(f"seed = {s} T = {t} L = {l}")
            utils.run_worm("FF_1D", ham_path, "", [l], t, int(1E6), 4)
# Out:
# seed = 0 T = 0.1 L = 6
# seed = 0 T = 0.1 L = 8
# create directory : "../worm_result/FF_1D_L_8/T_0.100000/N_1000000"
# seed = 0 T = 0.1 L = 11
# create directory : "../worm_result/FF_1D_L_11/T_0.100000/N_1000000"
# seed = 0 T = 0.1 L = 15
# create directory : "../worm_result/FF_1D_L_15/T_0.100000/N_1000000"
# seed = 0 T = 0.1 L = 21
# create directory : "../worm_result/FF_1D_L_21/T_0.100000/N_1000000"
# seed = 0 T = 0.1 L = 29
# create directory : "../worm_result/FF_1D_L_29/T_0.100000/N_1000000"
# seed = 0 T = 0.1 L = 39
# create directory : "../worm_result/FF_1D_L_39/T_0.100000/N_1000000"
# seed = 0 T = 0.1 L = 54
# create directory : "../worm_result/FF_1D_L_54/T_0.100000/N_1000000"
# seed = 0 T = 0.1 L = 73
# create directory : "../worm_result/FF_1D_L_73/T_0.100000/N_1000000"
# seed = 0 T = 0.1 L = 100
# create directory : "../worm_result/FF_1D_L_100/T_0.100000/N_1000000"
# seed = 0 T = 0.21544346900318834 L = 6
# seed = 0 T = 0.21544346900318834 L = 8
# create directory : "../worm_result/FF_1D_L_8/T_0.215400/N_1000000"
# seed = 0 T = 0.21544346900318834 L = 11
# seed = 0 T = 0.21544346900318834 L = 15
# seed = 0 T = 0.21544346900318834 L = 21
# create directory : "../worm_result/FF_1D_L_21/T_0.215400/N_1000000"
# seed = 0 T = 0.21544346900318834 L = 29
# create directory : "../worm_result/FF_1D_L_29/T_0.215400/N_1000000"
# seed = 0 T = 0.21544346900318834 L = 39
# create directory : "../worm_result/FF_1D_L_39/T_0.215400/N_1000000"
# seed = 0 T = 0.21544346900318834 L = 54
# create directory : "../worm_result/FF_1D_L_54/T_0.215400/N_1000000"
# seed = 0 T = 0.21544346900318834 L = 73
# seed = 0 T = 0.21544346900318834 L = 100
# create directory : "../worm_result/FF_1D_L_100/T_0.215400/N_1000000"
# seed = 0 T = 0.46415888336127786 L = 6
# seed = 0 T = 0.46415888336127786 L = 8
# create directory : "../worm_result/FF_1D_L_8/T_0.464200/N_1000000"
# seed = 0 T = 0.46415888336127786 L = 11
# create directory : "../worm_result/FF_1D_L_11/T_0.464200/N_1000000"
# seed = 0 T = 0.46415888336127786 L = 15
# create directory : "../worm_result/FF_1D_L_15/T_0.464200/N_1000000"
# seed = 0 T = 0.46415888336127786 L = 21
# create directory : "../worm_result/FF_1D_L_21/T_0.464200/N_1000000"
# seed = 0 T = 0.46415888336127786 L = 29
# create directory : "../worm_result/FF_1D_L_29/T_0.464200/N_1000000"
# seed = 0 T = 0.46415888336127786 L = 39
# create directory : "../worm_result/FF_1D_L_39/T_0.464200/N_1000000"
# seed = 0 T = 0.46415888336127786 L = 54
# create directory : "../worm_result/FF_1D_L_54/T_0.464200/N_1000000"
# seed = 0 T = 0.46415888336127786 L = 73
# create directory : "../worm_result/FF_1D_L_73/T_0.464200/N_1000000"
# seed = 0 T = 0.46415888336127786 L = 100
# create directory : "../worm_result/FF_1D_L_100/T_0.464200/N_1000000"
# seed = 0 T = 1.0 L = 6
# seed = 0 T = 1.0 L = 8
# create directory : "../worm_result/FF_1D_L_8/T_1.000000/N_1000000"
# seed = 0 T = 1.0 L = 11
# create directory : "../worm_result/FF_1D_L_11/T_1.000000/N_1000000"
# seed = 0 T = 1.0 L = 15
# create directory : "../worm_result/FF_1D_L_15/T_1.000000/N_1000000"
# seed = 0 T = 1.0 L = 21
# create directory : "../worm_result/FF_1D_L_21/T_1.000000/N_1000000"
# seed = 0 T = 1.0 L = 29
# create directory : "../worm_result/FF_1D_L_29/T_1.000000/N_1000000"
# seed = 0 T = 1.0 L = 39
# create directory : "../worm_result/FF_1D_L_39/T_1.000000/N_1000000"
# seed = 0 T = 1.0 L = 54
# create directory : "../worm_result/FF_1D_L_54/T_1.000000/N_1000000"
# seed = 0 T = 1.0 L = 73
# create directory : "../worm_result/FF_1D_L_73/T_1.000000/N_1000000"
# seed = 0 T = 1.0 L = 100
# create directory : "../worm_result/FF_1D_L_100/T_1.000000/N_1000000"
# seed = 1 T = 0.1 L = 6
# seed = 1 T = 0.1 L = 8
# seed = 1 T = 0.1 L = 11
# seed = 1 T = 0.1 L = 15
# seed = 1 T = 0.1 L = 21
# seed = 1 T = 0.1 L = 29
# seed = 1 T = 0.1 L = 39
# seed = 1 T = 0.1 L = 54
# seed = 1 T = 0.1 L = 73
# seed = 1 T = 0.1 L = 100
# seed = 1 T = 0.21544346900318834 L = 6
# seed = 1 T = 0.21544346900318834 L = 8
# seed = 1 T = 0.21544346900318834 L = 11
# seed = 1 T = 0.21544346900318834 L = 15
# seed = 1 T = 0.21544346900318834 L = 21
# seed = 1 T = 0.21544346900318834 L = 29
# seed = 1 T = 0.21544346900318834 L = 39
# seed = 1 T = 0.21544346900318834 L = 54
# seed = 1 T = 0.21544346900318834 L = 73
# seed = 1 T = 0.21544346900318834 L = 100
# seed = 1 T = 0.46415888336127786 L = 6
# seed = 1 T = 0.46415888336127786 L = 8
# seed = 1 T = 0.46415888336127786 L = 11
# seed = 1 T = 0.46415888336127786 L = 15
# seed = 1 T = 0.46415888336127786 L = 21
# seed = 1 T = 0.46415888336127786 L = 29
# seed = 1 T = 0.46415888336127786 L = 39
# seed = 1 T = 0.46415888336127786 L = 54
# seed = 1 T = 0.46415888336127786 L = 73
# seed = 1 T = 0.46415888336127786 L = 100
# seed = 1 T = 1.0 L = 6
# seed = 1 T = 1.0 L = 8
# seed = 1 T = 1.0 L = 11
# seed = 1 T = 1.0 L = 15
# seed = 1 T = 1.0 L = 21
# seed = 1 T = 1.0 L = 29
# seed = 1 T = 1.0 L = 39
# seed = 1 T = 1.0 L = 54
# seed = 1 T = 1.0 L = 73
# seed = 1 T = 1.0 L = 100
# seed = 2 T = 0.1 L = 6
# seed = 2 T = 0.1 L = 8
# seed = 2 T = 0.1 L = 11
# seed = 2 T = 0.1 L = 15
# seed = 2 T = 0.1 L = 21
# seed = 2 T = 0.1 L = 29
# seed = 2 T = 0.1 L = 39
# seed = 2 T = 0.1 L = 54
# seed = 2 T = 0.1 L = 73
# seed = 2 T = 0.1 L = 100
# seed = 2 T = 0.21544346900318834 L = 6
# seed = 2 T = 0.21544346900318834 L = 8
# seed = 2 T = 0.21544346900318834 L = 11
# seed = 2 T = 0.21544346900318834 L = 15
# seed = 2 T = 0.21544346900318834 L = 21
# seed = 2 T = 0.21544346900318834 L = 29
# seed = 2 T = 0.21544346900318834 L = 39
# seed = 2 T = 0.21544346900318834 L = 54
# seed = 2 T = 0.21544346900318834 L = 73
# seed = 2 T = 0.21544346900318834 L = 100
# seed = 2 T = 0.46415888336127786 L = 6
# seed = 2 T = 0.46415888336127786 L = 8
# seed = 2 T = 0.46415888336127786 L = 11
# seed = 2 T = 0.46415888336127786 L = 15
# seed = 2 T = 0.46415888336127786 L = 21
# seed = 2 T = 0.46415888336127786 L = 29
# seed = 2 T = 0.46415888336127786 L = 39
# seed = 2 T = 0.46415888336127786 L = 54
# seed = 2 T = 0.46415888336127786 L = 73
# seed = 2 T = 0.46415888336127786 L = 100
# seed = 2 T = 1.0 L = 6
# seed = 2 T = 1.0 L = 8
# seed = 2 T = 1.0 L = 11
# seed = 2 T = 1.0 L = 15
# seed = 2 T = 1.0 L = 21
# seed = 2 T = 1.0 L = 29
# seed = 2 T = 1.0 L = 39
# seed = 2 T = 1.0 L = 54
# seed = 2 T = 1.0 L = 73
# seed = 2 T = 1.0 L = 100
# seed = 3 T = 0.1 L = 6
# seed = 3 T = 0.1 L = 8
# seed = 3 T = 0.1 L = 11
# seed = 3 T = 0.1 L = 15
# seed = 3 T = 0.1 L = 21
# seed = 3 T = 0.1 L = 29
# seed = 3 T = 0.1 L = 39
# seed = 3 T = 0.1 L = 54
# seed = 3 T = 0.1 L = 73
# seed = 3 T = 0.1 L = 100
# seed = 3 T = 0.21544346900318834 L = 6
# seed = 3 T = 0.21544346900318834 L = 8
# seed = 3 T = 0.21544346900318834 L = 11
# seed = 3 T = 0.21544346900318834 L = 15
# seed = 3 T = 0.21544346900318834 L = 21
# seed = 3 T = 0.21544346900318834 L = 29
# seed = 3 T = 0.21544346900318834 L = 39
# seed = 3 T = 0.21544346900318834 L = 54
# seed = 3 T = 0.21544346900318834 L = 73
# seed = 3 T = 0.21544346900318834 L = 100
# seed = 3 T = 0.46415888336127786 L = 6
# seed = 3 T = 0.46415888336127786 L = 8
# seed = 3 T = 0.46415888336127786 L = 11
# seed = 3 T = 0.46415888336127786 L = 15
# seed = 3 T = 0.46415888336127786 L = 21
# seed = 3 T = 0.46415888336127786 L = 29
# seed = 3 T = 0.46415888336127786 L = 39
# seed = 3 T = 0.46415888336127786 L = 54
# seed = 3 T = 0.46415888336127786 L = 73
# seed = 3 T = 0.46415888336127786 L = 100
# seed = 3 T = 1.0 L = 6
# seed = 3 T = 1.0 L = 8
# seed = 3 T = 1.0 L = 11
# seed = 3 T = 1.0 L = 15
# seed = 3 T = 1.0 L = 21
# seed = 3 T = 1.0 L = 29
# seed = 3 T = 1.0 L = 39
# seed = 3 T = 1.0 L = 54
# seed = 3 T = 1.0 L = 73
# seed = 3 T = 1.0 L = 100
# seed = 4 T = 0.1 L = 6
# seed = 4 T = 0.1 L = 8
# seed = 4 T = 0.1 L = 11
# seed = 4 T = 0.1 L = 15
# seed = 4 T = 0.1 L = 21
# seed = 4 T = 0.1 L = 29
# seed = 4 T = 0.1 L = 39
# seed = 4 T = 0.1 L = 54
# seed = 4 T = 0.1 L = 73
# seed = 4 T = 0.1 L = 100
# seed = 4 T = 0.21544346900318834 L = 6
# seed = 4 T = 0.21544346900318834 L = 8
# seed = 4 T = 0.21544346900318834 L = 11
# seed = 4 T = 0.21544346900318834 L = 15
# seed = 4 T = 0.21544346900318834 L = 21
# seed = 4 T = 0.21544346900318834 L = 29
# seed = 4 T = 0.21544346900318834 L = 39
# seed = 4 T = 0.21544346900318834 L = 54
# seed = 4 T = 0.21544346900318834 L = 73
# seed = 4 T = 0.21544346900318834 L = 100
# seed = 4 T = 0.46415888336127786 L = 6
# seed = 4 T = 0.46415888336127786 L = 8
# seed = 4 T = 0.46415888336127786 L = 11
# seed = 4 T = 0.46415888336127786 L = 15
# seed = 4 T = 0.46415888336127786 L = 21
# seed = 4 T = 0.46415888336127786 L = 29
# seed = 4 T = 0.46415888336127786 L = 39
# seed = 4 T = 0.46415888336127786 L = 54
# seed = 4 T = 0.46415888336127786 L = 73
# seed = 4 T = 0.46415888336127786 L = 100
# seed = 4 T = 1.0 L = 6
# seed = 4 T = 1.0 L = 8
# seed = 4 T = 1.0 L = 11
# seed = 4 T = 1.0 L = 15
# seed = 4 T = 1.0 L = 21
# seed = 4 T = 1.0 L = 29
# seed = 4 T = 1.0 L = 39
# seed = 4 T = 1.0 L = 54
# seed = 4 T = 1.0 L = 73
# seed = 4 T = 1.0 L = 100
# seed = 5 T = 0.1 L = 6
# seed = 5 T = 0.1 L = 8
# seed = 5 T = 0.1 L = 11
# seed = 5 T = 0.1 L = 15
# seed = 5 T = 0.1 L = 21
# seed = 5 T = 0.1 L = 29
# seed = 5 T = 0.1 L = 39
# seed = 5 T = 0.1 L = 54
# seed = 5 T = 0.1 L = 73
# seed = 5 T = 0.1 L = 100
# seed = 5 T = 0.21544346900318834 L = 6
# seed = 5 T = 0.21544346900318834 L = 8
# seed = 5 T = 0.21544346900318834 L = 11
# seed = 5 T = 0.21544346900318834 L = 15
# seed = 5 T = 0.21544346900318834 L = 21
# seed = 5 T = 0.21544346900318834 L = 29
# seed = 5 T = 0.21544346900318834 L = 39
# seed = 5 T = 0.21544346900318834 L = 54
# seed = 5 T = 0.21544346900318834 L = 73
# seed = 5 T = 0.21544346900318834 L = 100
# seed = 5 T = 0.46415888336127786 L = 6
# seed = 5 T = 0.46415888336127786 L = 8
# seed = 5 T = 0.46415888336127786 L = 11
# seed = 5 T = 0.46415888336127786 L = 15
# seed = 5 T = 0.46415888336127786 L = 21
# seed = 5 T = 0.46415888336127786 L = 29
# seed = 5 T = 0.46415888336127786 L = 39
# seed = 5 T = 0.46415888336127786 L = 54
# seed = 5 T = 0.46415888336127786 L = 73
# seed = 5 T = 0.46415888336127786 L = 100
# seed = 5 T = 1.0 L = 6
# seed = 5 T = 1.0 L = 8
# seed = 5 T = 1.0 L = 11
# seed = 5 T = 1.0 L = 15
# seed = 5 T = 1.0 L = 21
# seed = 5 T = 1.0 L = 29
# seed = 5 T = 1.0 L = 39
# seed = 5 T = 1.0 L = 54
# seed = 5 T = 1.0 L = 73
# seed = 5 T = 1.0 L = 100
